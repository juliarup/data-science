# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# 1.	wstępna analiza danych i czyszczenie:
#
# a.	duplikaty
#
# b.	wartości odstające
#
# c.	spójność
#
# d.	braki w danych
#
# e.	skala wartości
#
# f.	inne

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("/content/drive/MyDrive/PAD/projektowa praca domowa/messy_data.csv")
df.head()
# Out:
#    carat  clarity  color       cut  x dimension  y dimension  z dimension  \
# 0    0.5       IF      D     Ideal          5.1         5.15          3.2
# 1    0.7     vvs2      E   premium          5.7                      3.52
# 2    NaN      Si2      h      Good          4.3         4.31
# 3    1.2       if      d     ideal                      6.82          4.2
# 4    0.9       I1      J      Fair            6                       3.7
#
#    depth  table   price
# 0   61.5           3000
# 1     62     59    4500
# 2   62.3     56     700
# 3   61.7     58   10000
# 4   61.7           2400

# %% [markdown]
#     carat (karat) – waga diamentu,
#     clarity (czystość) – klasyfikacja czystości diamentu,
#     color (kolor) – kolor diamentu,
#     cut (szlif) – jakość szlifu diamentu,
#     x dimension, y dimension, z dimension – wymiary diamentu,
#     depth (głębokość) – głębokość diamentu,
#     table (stołek) – szerokość górnej części diamentu w stosunku do najszerszego punktu,
#     price (cena) – cena diamentu.

# %% [markdown]
# # Wstępna analiza danych i czyszczenie

# %%
df
# Out:
#      carat  clarity  color         cut  x dimension  y dimension  z dimension  \
# 0     0.50       IF      D       Ideal          5.1         5.15          3.2
# 1     0.70     vvs2      E     premium          5.7                      3.52
# 2      NaN      Si2      h        Good          4.3         4.31
# 3     1.20       if      d       ideal                      6.82          4.2
# 4     0.90       I1      J        Fair            6                       3.7
# ..     ...      ...    ...         ...          ...          ...          ...
# 195   0.45      si1      F   very good          4.9         4.89
# 196   1.25     VVS2      H        Good          6.9                      4.27
# 197   0.55       i1      I     Premium          5.3                      3.28
# 198   0.85      Si2      E        fair          6.1         6.13         3.78
# 199    NaN     VVS1      G   Very good          6.4         6.43         3.97
#
#      depth  table    price
# 0     61.5            3000
# ...

# %% [markdown]
# ## Duplikaty

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 195    False
# 196    False
# 197    False
# 198    False
# 199    False
# Length: 200, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna()
# Out:
#      carat   clarity   color    cut   x dimension   y dimension   z dimension  \
# 0    False     False   False  False         False         False         False
# 1    False     False   False  False         False         False         False
# 2     True     False   False  False         False         False         False
# 3    False     False   False  False         False         False         False
# 4    False     False   False  False         False         False         False
# ..     ...       ...     ...    ...           ...           ...           ...
# 195  False     False   False  False         False         False         False
# 196  False     False   False  False         False         False         False
# 197  False     False   False  False         False         False         False
# 198  False     False   False  False         False         False         False
# 199   True     False   False  False         False         False         False
#
#       depth   table   price
# ...

# %% [markdown]
# ## Puste komórki

# %%
df.isna().any()
# Out:
# carat            True
#  clarity        False
#  color          False
#  cut            False
#  x dimension    False
#  y dimension    False
#  z dimension    False
#  depth          False
#  table          False
#  price          False
# dtype: bool

# %%
df.isna().sum()
# Out:
# carat           50
#  clarity         0
#  color           0
#  cut             0
#  x dimension     0
#  y dimension     0
#  z dimension     0
#  depth           0
#  table           0
#  price           0
# dtype: int64

# %%
#import numpy as np
df.replace({"?": np.nan, "--" : np.nan, " ": np.nan}, inplace=True)
df
# Out:
#      carat  clarity  color         cut  x dimension  y dimension  z dimension  \
# 0     0.50       IF      D       Ideal          5.1         5.15          3.2
# 1     0.70     vvs2      E     premium          5.7          NaN         3.52
# 2      NaN      Si2      h        Good          4.3         4.31          NaN
# 3     1.20       if      d       ideal          NaN         6.82          4.2
# 4     0.90       I1      J        Fair            6          NaN          3.7
# ..     ...      ...    ...         ...          ...          ...          ...
# 195   0.45      si1      F   very good          4.9         4.89          NaN
# 196   1.25     VVS2      H        Good          6.9          NaN         4.27
# 197   0.55       i1      I     Premium          5.3          NaN         3.28
# 198   0.85      Si2      E        fair          6.1         6.13         3.78
# 199    NaN     VVS1      G   Very good          6.4         6.43         3.97
#
#      depth  table    price
# ...

# %%
#df.dropna(inplace=True) # usuwa jeśli pojawi się 1 nan
#df

# %%
df.dropna(how='all', inplace=True) # usuń wiersze gdzie brakuje wszystkich wartości
df
# Out:
#      carat  clarity  color         cut  x dimension  y dimension  z dimension  \
# 0     0.50       IF      D       Ideal          5.1         5.15          3.2
# 1     0.70     vvs2      E     premium          5.7          NaN         3.52
# 2      NaN      Si2      h        Good          4.3         4.31          NaN
# 3     1.20       if      d       ideal          NaN         6.82          4.2
# 4     0.90       I1      J        Fair            6          NaN          3.7
# ..     ...      ...    ...         ...          ...          ...          ...
# 195   0.45      si1      F   very good          4.9         4.89          NaN
# 196   1.25     VVS2      H        Good          6.9          NaN         4.27
# 197   0.55       i1      I     Premium          5.3          NaN         3.28
# 198   0.85      Si2      E        fair          6.1         6.13         3.78
# 199    NaN     VVS1      G   Very good          6.4         6.43         3.97
#
#      depth  table    price
# ...

# %%
#df.dropna(subset=['ord_no', 'customer_id']) #usuwa gdy brakuje wartosci w poszczególnych kol

# %% [markdown]
# ## Spójność

# %% [markdown]
# ### Usuwanie białych znaków
# Nazwy atrybutów nie są znormalizowane, posiadają przerwy na początku i na końcu

# %%
# Wyświetl oryginalne nazwy kolumn
print("Oryginalne nazwy kolumn:")
print(df.columns)

# Zmiana nazw kolumn poprzez usuwanie białych znaków
df.rename(columns=lambda x: x.strip(), inplace=True)

df = df.rename(columns={'x dimension': 'x_dimension',
                        'y dimension': 'y_dimension',
                        'z dimension': 'z_dimension'
                        })

# Wyświetl zaktualizowane nazwy kolumn
print("\nZaktualizowane nazwy kolumn:")
print(df.columns)
# Out:
# Oryginalne nazwy kolumn:
# Index(['carat', ' clarity', ' color', ' cut', ' x dimension', ' y dimension',
#        ' z dimension', ' depth', ' table', ' price'],
#       dtype='object')
#
# Zaktualizowane nazwy kolumn:
# Index(['carat', 'clarity', 'color', 'cut', 'x_dimension', 'y_dimension',
#        'z_dimension', 'depth', 'table', 'price'],
#       dtype='object')

# %%
df['carat'].sum()
# Out:
# 119.85

# %% [markdown]
# ### typ danych
# Zmiana typu danych na podstawie zawartości tabeli

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   carat        150 non-null    float64
#  1   clarity      200 non-null    object
#  2   color        200 non-null    object
#  3   cut          200 non-null    object
#  4   x_dimension  197 non-null    object
#  5   y_dimension  136 non-null    object
#  6   z_dimension  152 non-null    object
#  7   depth        133 non-null    object
#  8   table        167 non-null    object
#  9   price        196 non-null    object
# dtypes: float64(1), object(9)
# memory usage: 15.8+ KB

# %%
df["x_dimension"] = df["x_dimension"].astype("float64")
df["y_dimension"] = df["y_dimension"].astype("float64")
df["z_dimension"] = df["z_dimension"].astype("float64")
df["depth"] = df["depth"].astype("float64")
df["table"] = df["table"].astype("float64") # nie można zamienić nan na int
df["price"] = df["price"].astype("float64")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   carat        150 non-null    float64
#  1   clarity      200 non-null    object
#  2   color        200 non-null    object
#  3   cut          200 non-null    object
#  4   x_dimension  197 non-null    float64
#  5   y_dimension  136 non-null    float64
#  6   z_dimension  152 non-null    float64
#  7   depth        133 non-null    float64
#  8   table        167 non-null    float64
#  9   price        196 non-null    float64
# dtypes: float64(7), object(3)
# memory usage: 15.8+ KB

# %% [markdown]
# ---

# %% [markdown]
# ### Sprawdzanie spójności atrybutów w poszczególnych kolumnach

# %% [markdown]
# W kolumnie "color" obserwacje mają różnej wielkości lietry, przyjmuję, że jest to błąd i zmieniam wszystkie na małe litery, żeby były spójne

# %%
df.head()
# Out:
#    carat clarity color       cut  x_dimension  y_dimension  z_dimension  \
# 0    0.5      IF     D     Ideal          5.1         5.15         3.20
# 1    0.7    vvs2     E   premium          5.7          NaN         3.52
# 2    NaN     Si2     h      Good          4.3         4.31          NaN
# 3    1.2      if     d     ideal          NaN         6.82         4.20
# 4    0.9      I1     J      Fair          6.0          NaN         3.70
#
#    depth  table    price
# 0   61.5    NaN   3000.0
# 1   62.0   59.0   4500.0
# 2   62.3   56.0    700.0
# 3   61.7   58.0  10000.0
# 4   61.7    NaN   2400.0

# %%
print("przed: ")
print(df["color"].value_counts())
print("---")
print("po: ")
df["color"] = df["color"].str.lower()
print(df["color"].value_counts())
# Out:
# przed:
#  G            36
#  I            33
#  H            30
#  F            24
#  D            13
#  E            13
#  e            12
#  d             9
#  f             6
#  j             6
#  colorless     6
#  h             4
#  g             4
#  J             2
#  Colorless     2
# Name: color, dtype: int64
# ---
# po:
#  g            40
#  h            34
#  i            33
#  f            30
#  e            25
#  d            22
#  j             8
#  colorless     8
# Name: color, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# W kolumnie 'cut' podobnie, zmieniam liery na małe

# %%
print(df["cut"].value_counts())
print("---")
df["cut"] = df["cut"].str.lower()
print(df["cut"].value_counts())
# Out:
#  Premium      34
#  Good         30
#  fair         24
#  Ideal        23
#  good         21
#  very good    19
#  Fair         12
#  Very good    10
#  ideal         9
#  Very Good     9
#  premium       7
#  very Good     2
# Name: cut, dtype: int64
# ---
#  good         51
#  premium      41
#  very good    40
#  fair         36
#  ideal        32
# Name: cut, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# Ponownie ten sam zabieg w kolumnie 'clarity'

# %%
print(df["clarity"].value_counts())
print("---")
df["clarity"] = df["clarity"].str.lower()
print(df["clarity"].value_counts())
# Out:
#  i1      26
#  si2     23
#  VVS1    23
#  IF      20
#  VVS2    19
#  vvs2    18
#  si1     18
#  Si2     16
#  Si1     12
#  vvs1    11
#  I1       5
#  SI2      5
#  if       3
#  Vvs1     1
# Name: clarity, dtype: int64
# ---
#  si2     44
#  vvs2    37
#  vvs1    35
#  i1      31
#  si1     30
#  if      23
# Name: clarity, dtype: int64

# %% [markdown]
# ## sumuję poszczególne kolumny

# %% [markdown]
# W celu sprawdzenia czy znajdują się tam wartości numeryczne

# %%
df['price'].sum()
# Out:
# 2236500.0

# %%
df['z_dimension'].sum()
# Out:
# 561.5899999999999

# %% [markdown]
# ---

# %% [markdown]
# Sprawdzenie czy podane atrybuty są typu float

# %%
'''df['is_alphnum'] = list(map(lambda x: x.isalnum(), df['name_code']))
df
df['is_num'] = list(map(lambda x: x.isdigit(), df['company_code']))
df'''
# Out:
# "df['is_alphnum'] = list(map(lambda x: x.isalnum(), df['name_code']))\ndf\ndf['is_num'] = list(map(lambda x: x.isdigit(), df['company_code']))\ndf"

# %%
columns_to_check = ['carat', 'x_dimension', 'y_dimension', 'z_dimension', 'depth', 'table', 'price', 'cut']

for column in columns_to_check:
    is_float_column = pd.api.types.is_float_dtype(df[column])
    print(f"{is_float_column}  '{column}'")
# Out:
# True  'carat'
# True  'x_dimension'
# True  'y_dimension'
# True  'z_dimension'
# True  'depth'
# True  'table'
# True  'price'
# False  'cut'

# %% [markdown]
# ## Duplikaty
# Sprawdzenie duplikatów po wykonaniu spójności

# %%
df.duplicated()
df.duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#      carat clarity color         cut  x_dimension  y_dimension  z_dimension  \
# 0     0.50      if     d       ideal          5.1         5.15         3.20
# 1     0.70    vvs2     e     premium          5.7          NaN         3.52
# 2      NaN     si2     h        good          4.3         4.31          NaN
# 3     1.20      if     d       ideal          NaN         6.82         4.20
# 4     0.90      i1     j        fair          6.0          NaN         3.70
# ..     ...     ...   ...         ...          ...          ...          ...
# 195   0.45     si1     f   very good          4.9         4.89          NaN
# 196   1.25    vvs2     h        good          6.9          NaN         4.27
# 197   0.55      i1     i     premium          5.3          NaN         3.28
# 198   0.85     si2     e        fair          6.1         6.13         3.78
# 199    NaN    vvs1     g   very good          6.4         6.43         3.97
#
#      depth  table     price
# ...

# %% [markdown]
# ### Sprawdzenie duplikatów różnymi sposobami, np. po wybranych atrybutach

# %% [markdown]
# `.duplicated()` skorzystać z dwóch argumentów: `subset` i `keep`. Dla argumentu subset podaj listę nazw kolumn, w których chcemy sprawdzić duplikaty, a w argumencie keep podaj  1 z 3 wartości: „pierwsza”, „ostatnia” lub „Fałsz”. Z dokumentacji wiemy, że:
# - `first` : Oznacz duplikaty jako True z wyjątkiem pierwszego wystąpienia.
# - `last` : Zaznacz duplikaty jako True z wyjątkiem ostatniego wystąpienia.
# - `False` : Oznacz wszystkie duplikaty jako True.

# %%
duplicates = df.duplicated (subset=["depth", "table", "price"], keep=False)

df[duplicates]
# Out:
#      carat clarity color         cut  x_dimension  y_dimension  z_dimension  \
# 29     NaN    vvs1     d       ideal          6.7         6.71         4.15
# 73    1.20    vvs1     e     premium          6.8          NaN         4.20
# 103   0.65     si2     i        fair          5.6         5.59         3.46
# 131   1.30     si2     h        fair          7.0          NaN         4.33
# 134    NaN      i1     g        good          5.6          NaN         3.46
# 140   0.95    vvs2     g       ideal          6.4         6.41         3.97
# 144   0.65     si2     e        good          5.6         5.58         3.47
# 166   0.90     si2     g     premium          6.3         6.31         3.90
# 172   0.95     si2     d        good          6.4         6.38         3.96
# 193    NaN    vvs2     e        good          6.3          NaN         3.90
# 194   0.95     si1     g       ideal          6.4         6.42         3.96
# ...

# %%
## Posortuj zduplikowane wartości według odpowiedniego indeksu
df[duplicates].sort_values("price")
# Out:
#      carat clarity color         cut  x_dimension  y_dimension  z_dimension  \
# 134    NaN      i1     g        good          5.6          NaN         3.46
# 195   0.45     si1     f   very good          4.9         4.89          NaN
# 103   0.65     si2     i        fair          5.6         5.59         3.46
# 144   0.65     si2     e        good          5.6         5.58         3.47
# 140   0.95    vvs2     g       ideal          6.4         6.41         3.97
# 166   0.90     si2     g     premium          6.3         6.31         3.90
# 172   0.95     si2     d        good          6.4         6.38         3.96
# 194   0.95     si1     g       ideal          6.4         6.42         3.96
# 29     NaN    vvs1     d       ideal          6.7         6.71         4.15
# 193    NaN    vvs2     e        good          6.3          NaN         3.90
# 73    1.20    vvs1     e     premium          6.8          NaN         4.20
# ...

# %%
duplicates2 = df.duplicated (subset=["carat", "color", "price"], keep=False)

df[duplicates2].sort_values("carat")
# Out:
#      carat clarity color         cut  x_dimension  y_dimension  z_dimension  \
# 40    0.45     si2     h       ideal          4.8         4.82         3.01
# 99    0.45     si2     h       ideal          4.8         4.79         2.97
# 155   0.50    vvs1     i        fair          5.1         5.12          NaN
# 186   0.50     si2     e     premium          5.1         5.11          NaN
# 132   0.50    vvs1     i       ideal          5.2         5.19          NaN
# 53    0.50    vvs1     e     premium          5.2         5.22          NaN
# 142   0.55    vvs1     h        fair          5.3          NaN         3.29
# 102   0.55    vvs1     h        good          5.3         5.29          NaN
# 119   0.60    vvs1     h        good          5.5         5.49          NaN
# 167   0.60      if     h   very good          5.5         5.49         3.41
# 117   0.75     si2     f       ideal          5.8         5.77         3.59
# ...

# %%
#df.to_csv('/content/drive/MyDrive/PAD/projektowa praca domowa/modified_data.csv', index=False)

# %% [markdown]
# Na podstawie powyższych operacji, można stwierdzić, że w zbiorze danych nie występują dupliakty

# %% [markdown]
# ## Brakujące wartości
# Brakujące wartości typu float zostaną zamienione na średnią w danej kolumnie, pozostałe wartości zostaną uzupełnione modą

# %%
columns = df.columns.to_list()

for column in columns:
    if  isinstance(df[column], float):
        df[column].fillna(df[column].mean(), inplace = True)
    else:
        df[column].fillna(df[column].mode()[0], inplace=True)

"""df['carat'].fillna(df['carat'].mean(), inplace=True) # średnia
df['x dimension'].fillna(df['x dimension'].mean(), inplace=True)
df['y dimension'].fillna(df['y dimension'].mean(), inplace=True)
df['z dimension'].fillna(df['z dimension'].mean(), inplace=True)
df['depth'].fillna(df['depth'].mean(), inplace=True)
df['table'].fillna(df['table'].mean(), inplace=True)
df['price'].fillna(df['price'].mean(), inplace=True)"""
# Out:
# "df['carat'].fillna(df['carat'].mean(), inplace=True) # średnia\ndf['x dimension'].fillna(df['x dimension'].mean(), inplace=True)\ndf['y dimension'].fillna(df['y dimension'].mean(), inplace=True)\ndf['z dimension'].fillna(df['z dimension'].mean(), inplace=True)\ndf['depth'].fillna(df['depth'].mean(), inplace=True)\ndf['table'].fillna(df['table'].mean(), inplace=True)\ndf['price'].fillna(df['price'].mean(), inplace=True)"

# %%
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   carat        200 non-null    float64
#  1   clarity      200 non-null    object
#  2   color        200 non-null    object
#  3   cut          200 non-null    object
#  4   x_dimension  200 non-null    float64
#  5   y_dimension  200 non-null    float64
#  6   z_dimension  200 non-null    float64
#  7   depth        200 non-null    float64
#  8   table        200 non-null    float64
#  9   price        200 non-null    float64
# dtypes: float64(7), object(3)
# memory usage: 15.8+ KB
#      carat clarity color         cut  x_dimension  y_dimension  z_dimension  \
# 0     0.50      if     d       ideal          5.1         5.15         3.20
# 1     0.70    vvs2     e     premium          5.7         5.49         3.52
# ...

# %%
df.isna().sum()
# Out:
# carat          0
# clarity        0
# color          0
# cut            0
# x_dimension    0
# y_dimension    0
# z_dimension    0
# depth          0
# table          0
# price          0
# dtype: int64

# %%
#df.to_csv('/content/drive/MyDrive/PAD/projektowa praca domowa/cleaned_data.csv', index=False)

# %% [markdown]
# # Wizualizacja
# w osobnym pliku
